# %%
# !pip install folium

# %%
import folium 
print('folium is imported successfully')
# Out:
# folium is imported successfully

# %% [markdown]
# # longitude = 33.8869
# lattitude = 9.5375
# tunisia_map = folium.Map(location = [longitude,lattitude],zoom_start = 6, tiles="OpenStreetMap")
# tunisia_map

# %%
# San Francisco latitude and longitude values
latitude = 37.77
longitude = -122.42
# create map and display it
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=8)

# display the map of San Francisco
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd 
print('pandas imported successfully')
# Out:
# pandas imported successfully

# %%
data_path = r'Police_Department_Incidents_-_Previous_Year__2016_.csv'
incident_df = pd.read_csv(data_path)

# %%
incident_df.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# ...

# %%
incident_df = incident_df.head(100)

# %%
from folium import plugins

#instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(sanfran_map)

for long, lat in zip(incident_df.X, incident_df.Y):
    # loop through the 100 crimes and add each to the incidents feature group
    incidents.add_child(
        folium.CircleMarker(
            [lat,long],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )
# add pop-up text to each marker on the map
latitudes = list(incident_df.Y)
longitudes = list(incident_df.X)
labels = list(incident_df.Category)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label, icon=None).add_to(sanfran_map)    
# add incidents to map
sanfran_map.add_child(incidents)
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for long, lat in zip(incident_df.X, incident_df.Y):
    print(long, lat)
# Out:
# -122.403404791479 37.775420706711
# -122.403404791479 37.775420706711
# -122.388856204292 37.7299809672996
# -122.412970537591 37.7857883766888
# -122.419671780296 37.7650501214668
# -122.426077177375 37.788018555829
# -122.405721454567 37.7808789360214
# -122.411778295992 37.7839805592634
# -122.393357241451 37.7757876218293
# -122.387181635995 37.7209669615499
# -122.477376524003 37.7644781578695
# -122.477960327299 37.7457389429655
# -122.37675765553 37.7356970275482
# -122.432325871028 37.7292705199592
# -122.40090869889 37.791642982384
# -122.408595110869 37.7837069301545
# -122.406870402082 37.7572895904578
# -122.420354780861 37.7489063051829
# -122.439909766772 37.715765426995
# -122.408421116922 37.7835699386918
# -122.422315670749 37.7736186276456
# -122.424519835009 37.7928412840447
# -122.414233849038 37.7540986882068
# -122.414233849038 37.7540986882068
# -122.507750131004 37.7714939969416
# -122.474444639595 37.718302204766
# -122.427562596985 37.7645752317615
# ...
